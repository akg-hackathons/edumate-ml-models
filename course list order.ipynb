# %%
import pandas as pd

# %%
df=pd.read_csv('udemy_courses.csv')
df
# Out:
#       course_id                                       course_title  \
# 0             1                 Ultimate Investment Banking Course
# 1             2  Complete GST Course & Certification - Grow You...
# 2             3  Financial Modeling for Business Analysts and C...
# 3             4  Beginner to Pro - Financial Analysis in Excel ...
# 4             5       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3678       3679  Learn jQuery from Scratch - Master of JavaScri...
# 3679       3680  How To Design A WordPress Website With No Codi...
# 3680       3681                      Learn and Build using Polymer
# 3681       3682  CSS Animations: Create Amazing Effects on Your...
# 3682       3683  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url is_paid price  \
# 0     https://www.udemy.com/ultimate-investment-bank...    TRUE   200
# ...

# %%
df.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     681
# Graphic Design          603
# Name: subject, dtype: int64

# %%
df1=df.sort_values(['subject','num_reviews'])
df1
# Out:
#       course_id                                       course_title  \
# 215         216  Preparation of Consolidated Financial Statemen...
# 258         259     Fundamentals of Accounting for Business Owners
# 381         382  Covered Calls - Powerful Income Strategy for S...
# 407         408     Corporate Internal Controls and Fraud Controls
# 410         411                             Trading Options Basics
# ...         ...                                                ...
# 3259       3260                            Modern React with Redux
# 3252       3253          JavaScript: Understanding the Weird Parts
# 3209       3210  Angular 4 (formerly Angular 2) - The Complete ...
# 3237       3238              The Complete Web Developer Course 2.0
# 3235       3236                         The Web Developer Bootcamp
#
#                                                     url is_paid price  \
# 215   https://www.udemy.com/preparation-of-consolida...   FALSE  Free
# ...

# %%
df1.to_csv('Final.csv')

# %%
df2=df[df['subject']=='Web Development'].sort_values('num_reviews', ascending=[0])
df2
# Out:
#       course_id                                       course_title  \
# 3235       3236                         The Web Developer Bootcamp
# 3237       3238              The Complete Web Developer Course 2.0
# 3209       3210  Angular 4 (formerly Angular 2) - The Complete ...
# 3252       3253          JavaScript: Understanding the Weird Parts
# 3259       3260                            Modern React with Redux
# ...         ...                                                ...
# 3653       3654                      Mastering Unix : AWK Commands
# 2650       2651                            Angular 4 Front To Back
# 3585       3586                          XSD :basics for beginners
# 2593       2594    Effective Personal Website Building and Hosting
# 3631       3632                        AppML :basics for beginners
#
#                                                     url is_paid price  \
# 3235  https://www.udemy.com/the-web-developer-bootcamp/    TRUE   200
# ...

# %%
df1.head().drop(['course_id','num_subscribers','published_timestamp','subject'], axis=1)
# df1.drop(df1.columns[df1.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True).head
# Out:
#                                           course_title  \
# 215  Preparation of Consolidated Financial Statemen...
# 258     Fundamentals of Accounting for Business Owners
# 381  Covered Calls - Powerful Income Strategy for S...
# 407     Corporate Internal Controls and Fraud Controls
# 410                             Trading Options Basics
#
#                                                    url is_paid price  \
# 215  https://www.udemy.com/preparation-of-consolida...   FALSE  Free
# 258  https://www.udemy.com/fundamentals-of-accounti...    TRUE    20
# 381  https://www.udemy.com/covered-calls-income-str...    TRUE    60
# 407  https://www.udemy.com/corporate-internal-contr...    TRUE    50
# 410      https://www.udemy.com/trading-options-basics/    TRUE   200
#
#      num_reviews  num_lectures               level content_duration
# 215            0            18  Intermediate Level        1.5 hours
# 258            0            47      Beginner Level        2.5 hours
# ...
